# %% [markdown]
# ## Lab 2
# ### Part 2: Dealing with overfitting

# %% [markdown]
# Today we work with [Fashion-MNIST dataset](https://github.com/zalandoresearch/fashion-mnist) (*hint: it is available in `torchvision`*).
#
# Your goal for today:
# 1. Train a FC (fully-connected) network that achieves >= 0.885 test accuracy.
# 2. Cause considerable overfitting by modifying the network (e.g. increasing the number of network parameters and/or layers) and demonstrate in in the appropriate way (e.g. plot loss and accurasy on train and validation set w.r.t. network complexity).
# 3. Try to deal with overfitting (at least partially) by using regularization techniques (Dropout/Batchnorm/...) and demonstrate the results.
#
# __Please, write a small report describing your ideas, tries and achieved results in the end of this file.__
#
# *Note*: Tasks 2 and 3 are interrelated, in task 3 your goal is to make the network from task 2 less prone to overfitting. Task 1 is independent from 2 and 3.
#
# *Note 2*: We recomment to use Google Colab or other machine with GPU acceleration.

# %%
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
import torchsummary
import torch.utils.data
from IPython.display import clear_output
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure
import numpy as np
from sklearn.metrics import accuracy_score
import os
import torch.nn.functional as F


device = 'cuda:0' if torch.cuda.is_available() else 'cpu'

# %%
# Technical function
def mkdir(path):
    if not os.path.exists(root_path):
        os.mkdir(root_path)
        print('Directory', path, 'is created!')
    else:
        print('Directory', path, 'already exists!')
        
root_path = 'fmnist'
mkdir(root_path)
# Out:
# Directory fmnist is created!

# %%
download = True
train_transform = transforms.ToTensor()
test_transform = transforms.ToTensor()
transforms.Compose((transforms.ToTensor()))


fmnist_dataset_train = torchvision.datasets.FashionMNIST(root_path, 
                                                        train=True, 
                                                        transform=train_transform,
                                                        target_transform=None,
                                                        download=download)
fmnist_dataset_test = torchvision.datasets.FashionMNIST(root_path, 
                                                       train=False, 
                                                       transform=test_transform,
                                                       target_transform=None,
                                                       download=download)
# Out:
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz to fmnist/FashionMNIST/raw/train-images-idx3-ubyte.gz
#   0%|          | 0/26421880 [00:00<?, ?it/s]
# Extracting fmnist/FashionMNIST/raw/train-images-idx3-ubyte.gz to fmnist/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz to fmnist/FashionMNIST/raw/train-labels-idx1-ubyte.gz
#   0%|          | 0/29515 [00:00<?, ?it/s]
# Extracting fmnist/FashionMNIST/raw/train-labels-idx1-ubyte.gz to fmnist/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz to fmnist/FashionMNIST/raw/t10k-images-idx3-ubyte.gz
#   0%|          | 0/4422102 [00:00<?, ?it/s]
# Extracting fmnist/FashionMNIST/raw/t10k-images-idx3-ubyte.gz to fmnist/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz to fmnist/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz
#   0%|          | 0/5148 [00:00<?, ?it/s]
# Extracting fmnist/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz to fmnist/FashionMNIST/raw

# %%
train_loader = torch.utils.data.DataLoader(fmnist_dataset_train, 
                                           batch_size=128,
                                           shuffle=True,
                                           num_workers=2)
test_loader = torch.utils.data.DataLoader(fmnist_dataset_test,
                                          batch_size=256,
                                          shuffle=False,
                                          num_workers=2)

# %%
len(fmnist_dataset_test)
# Out:
# 10000

# %% [markdown]
# ### Task 1
# Train a network that achieves $\geq 0.885$ test accuracy. It's fine to use only Linear (`nn.Linear`) layers and activations/dropout/batchnorm. Convolutional layers might be a great use, but we will meet them a bit later.

# %%
class TinyNeuralNetwork(nn.Module):
    def __init__(self, input_shape=28*28, num_classes=10, input_channels=1):
        super(self.__class__, self).__init__()
        self.model = nn.Sequential(
            nn.Flatten(), # This layer converts image into a vector to use Linear layers afterwards
            # Your network structure comes here
            nn.BatchNorm1d(input_shape),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(input_shape, 512),
            nn.BatchNorm1d(512),
            nn.Dropout(0.2),
            nn.ReLU(),
            nn.Linear(512, 256),
            nn.BatchNorm1d(256),
            nn.Linear(256, 64),
            nn.BatchNorm1d(64),
            nn.ReLU(),
            nn.Linear(64, 10)
        )
        
    def forward(self, inp):    
        out = self.model(inp)
        return out

# %%
torchsummary.summary(TinyNeuralNetwork().to(device), (28*28,))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#            Flatten-1                  [-1, 784]               0
#        BatchNorm1d-2                  [-1, 784]           1,568
#               ReLU-3                  [-1, 784]               0
#            Dropout-4                  [-1, 784]               0
#             Linear-5                  [-1, 512]         401,920
#        BatchNorm1d-6                  [-1, 512]           1,024
#            Dropout-7                  [-1, 512]               0
#               ReLU-8                  [-1, 512]               0
#             Linear-9                  [-1, 256]         131,328
#       BatchNorm1d-10                  [-1, 256]             512
#            Linear-11                   [-1, 64]          16,448
#       BatchNorm1d-12                   [-1, 64]             128
#              ReLU-13                   [-1, 64]               0
#            Linear-14                   [-1, 10]             650
# ================================================================
# Total params: 553,578
# Trainable params: 553,578
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.04
# Params size (MB): 2.11
# Estimated Total Size (MB): 2.16
# ----------------------------------------------------------------

# %% [markdown]
# Your experiments come here:

# %%
model = TinyNeuralNetwork().to(device)
opt = torch.optim.Adam(model.parameters(), lr = 0.05)
loss_func = nn.CrossEntropyLoss()

# Your experiments, training and validation loops here
epochs = 50

min_valid_loss = np.inf

for epoch in range(epochs):
    train_loss = 0.0
    for data, labels in train_loader:
        # Transfer Data to GPU if available
        if torch.cuda.is_available():
            data, labels = data.cuda(), labels.cuda()
         
        opt.zero_grad()
        target = model(data)
        loss = loss_func(target, labels)
        loss.backward()

        opt.step()

        train_loss += loss.item()
     
    valid_loss = 0.0
    model.eval()     # Optional when not using Model Specific layer
    for data, labels in test_loader:
        # Transfer Data to GPU if available
        if torch.cuda.is_available():
            data, labels = data.cuda(), labels.cuda()
         
        target = model(data)
        loss = loss_func(target,labels)
        valid_loss += loss.item()
 
    print(f'Epoch {epoch+1} \t\t Training Loss: {train_loss / len(train_loader)} \t\t Validation Loss: {valid_loss / len(test_loader)}')
     
    if min_valid_loss > valid_loss:
        print(f'Validation Loss Decreased({min_valid_loss:.6f}--->{valid_loss:.6f}) \t Saving The Model')
        min_valid_loss = valid_loss
         
        # Saving State Dict
        torch.save(model.state_dict(), 'saved_model.pth')
# Out:
# Epoch 1 		 Training Loss: 0.6108481383908277 		 Validation Loss: 0.43716992512345315
# Validation Loss Decreased(inf--->17.486797) 	 Saving The Model
# Epoch 1 has accurcy score of test data: 0.838
# Epoch 2 		 Training Loss: 0.3794445709696711 		 Validation Loss: 0.42567205280065534
# Validation Loss Decreased(17.486797--->17.026882) 	 Saving The Model
# Epoch 2 has accurcy score of test data: 0.838
# Epoch 3 		 Training Loss: 0.3225026708612564 		 Validation Loss: 0.3495135050266981
# Validation Loss Decreased(17.026882--->13.980540) 	 Saving The Model
# Epoch 3 has accurcy score of test data: 0.868
# Epoch 4 		 Training Loss: 0.29075109888749845 		 Validation Loss: 0.35751201324164866
# Epoch 4 has accurcy score of test data: 0.866
# Epoch 5 		 Training Loss: 0.2651501383417959 		 Validation Loss: 0.33244835808873174
# Validation Loss Decreased(13.980540--->13.297934) 	 Saving The Model
# Epoch 5 has accurcy score of test data: 0.877
# Epoch 6 		 Training Loss: 0.246120250714359 		 Validation Loss: 0.3341763600707054
# Epoch 6 has accurcy score of test data: 0.882
# Epoch 7 		 Training Loss: 0.2290510637228931 		 Validation Loss: 0.33960279896855355
# Epoch 7 has accurcy score of test data: 0.881
# Epoch 8 		 Training Loss: 0.21317269966038052 		 Validation Loss: 0.3394684616476297
# Epoch 8 has accurcy score of test data: 0.884
# Epoch 9 		 Training Loss: 0.19902887236652597 		 Validation Loss: 0.32717535868287084
# Validation Loss Decreased(13.297934--->13.087014) 	 Saving The Model
# Epoch 9 has accurcy score of test data: 0.889
# Epoch 10 		 Training Loss: 0.18640250558537969 		 Validation Loss: 0.32845894806087017
# Epoch 10 has accurcy score of test data: 0.888

# %%
test_loss = 0.0
total = 0
correct = 0

for data,label in test_loader:
    data, label = data.cuda(), label.cuda()
    prediction = model(data)
    for x,label in zip(torch.argmax(prediction,axis = 1),label):
        if x == label:
            correct += 1
        total += 1
    loss = loss_func(prediction,label)
    test_loss += loss.item() * data.size(0)

test_loss = test_loss/len(test_loader)
correct_proportion = correct/total                          
print('Testing Loss: ', test_loss)
print('Correct Predictions: ', correct_proportion)
# Out:
# Testing Loss:83.84315204620361
# Correct Predictions: 8858/10000

# %% [markdown]
# ### Task 2: Overfit it.
# Build a network that will overfit to this dataset. Demonstrate the overfitting in the appropriate way (e.g. plot loss and accurasy on train and test set w.r.t. network complexity).
#
# *Note:* you also might decrease the size of `train` dataset to enforce the overfitting and speed up the computations.

# %%
train_ds, val_ds = torch.utils.data.random_split(fmnist_dataset_test, [9000, 1000])
train_ds, val_ds = torch.utils.data.random_split(val_ds, [900, 100])

# %%
train_loader = torch.utils.data.DataLoader(train_ds, 
                                           batch_size=512,
                                           shuffle=True,
                                           num_workers=2)
test_loader = torch.utils.data.DataLoader(val_ds,
                                          batch_size=128,
                                          shuffle=False,
                                          num_workers=2)

# %%
class OverfittingNeuralNetwork(nn.Module):
    def __init__(self, input_shape=28*28, num_classes=10, input_channels=1):
        super(self.__class__, self).__init__()
        self.model = nn.Sequential(
            nn.Flatten(), # This layer converts image into a vector to use Linear layers afterwards
            nn.Linear(input_shape, num_classes)
        )
        
    def forward(self, inp):       
        out = self.model(inp)
        return out

# %%
torchsummary.summary(OverfittingNeuralNetwork().to(device), (28*28,))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#            Flatten-1                  [-1, 784]               0
#             Linear-2                  [-1, 512]         401,920
#             Linear-3                  [-1, 256]         131,328
#             Linear-4                  [-1, 128]          32,896
#             Linear-5                   [-1, 10]           1,290
# ================================================================
# Total params: 567,434
# Trainable params: 567,434
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.01
# Params size (MB): 2.16
# Estimated Total Size (MB): 2.18
# ----------------------------------------------------------------

# %%
model = OverfittingNeuralNetwork().to(device)
opt = torch.optim.Adam(model.parameters(), lr = 0.05)
loss_func = nn.CrossEntropyLoss()

# Your experiments, training and validation loops here
epochs = 50

min_valid_loss = np.inf

for epoch in range(epochs):
    train_loss = 0.0
    for data, labels in train_loader:
        # Transfer Data to GPU if available
        if torch.cuda.is_available():
            data, labels = data.cuda(), labels.cuda()
         
        opt.zero_grad()
        target = model(data)
        loss = loss_func(target, labels)
        loss.backward()

        opt.step()

        train_loss += loss.item()
     
    valid_loss = 0.0
    model.eval()     # Optional when not using Model Specific layer
    for data, labels in test_loader:
        # Transfer Data to GPU if available
        if torch.cuda.is_available():
            data, labels = data.cuda(), labels.cuda()
         
        target = model(data)
        loss = loss_func(target,labels)
        valid_loss += loss.item()
 
    print(f'Epoch {epoch+1} \t\t Training Loss: {train_loss / len(train_loader)} \t\t Validation Loss: {valid_loss / len(test_loader)}')
     
    if min_valid_loss > valid_loss:
        print(f'Validation Loss Decreased({min_valid_loss:.6f}--->{valid_loss:.6f}) \t Saving The Model')
        min_valid_loss = valid_loss
         
        # Saving State Dict
        torch.save(model.state_dict(), 'saved_model.pth')
# Out:
# Epoch 1 		 Training Loss: 2.4264168739318848 		 Validation Loss: 9.546398162841797
# Validation Loss Decreased(inf--->9.546398) 	 Saving The Model
# Epoch 0 has accurcy score of train data: 0.312
# Epoch 2 		 Training Loss: 11.059917449951172 		 Validation Loss: 17.9643497467041
# Epoch 1 has accurcy score of train data: 0.193
# Epoch 3 		 Training Loss: 16.81727123260498 		 Validation Loss: 13.834010124206543
# Epoch 2 has accurcy score of train data: 0.415
# Epoch 4 		 Training Loss: 11.151932716369629 		 Validation Loss: 35.456565856933594
# Epoch 3 has accurcy score of train data: 0.082
# Epoch 5 		 Training Loss: 26.31991481781006 		 Validation Loss: 14.99642562866211
# Epoch 4 has accurcy score of train data: 0.363
# Epoch 6 		 Training Loss: 16.192634105682373 		 Validation Loss: 10.36890983581543
# Epoch 5 has accurcy score of train data: 0.353
# Epoch 7 		 Training Loss: 10.688169479370117 		 Validation Loss: 7.47598123550415
# Validation Loss Decreased(9.546398--->7.475981) 	 Saving The Model
# Epoch 6 has accurcy score of train data: 0.430
# Epoch 8 		 Training Loss: 8.104997634887695 		 Validation Loss: 4.904947280883789
# Validation Loss Decreased(7.475981--->4.904947) 	 Saving The Model
# Epoch 7 has accurcy score of train data: 0.492
# Epoch 9 		 Training Loss: 5.850419998168945 		 Validation Loss: 8.143148422241211
# Epoch 8 has accurcy score of train data: 0.405
# Epoch 10 		 Training Loss: 9.052851676940918 		 Validation Loss: 7.236251354217529
# Epoch 9 has accurcy score of train data: 0.474
# Epoch 11 		 Training Loss: 6.9119486808776855 		 Validation Loss: 5.7506184577941895
# Epoch 10 has accurcy score of train data: 0.482
# Epoch 12 		 Training Loss: 5.024099349975586 		 Validation Loss: 4.524194717407227
# Validation Loss Decreased(4.904947--->4.524195) 	 Saving The Model
# Epoch 11 has accurcy score of train data: 0.541
# Epoch 13 		 Training Loss: 4.0922181606292725 		 Validation Loss: 5.710428237915039
# Epoch 12 has accurcy score of train data: 0.601
# Epoch 14 		 Training Loss: 4.085197567939758 		 Validation Loss: 4.249089241027832
# Validation Loss Decreased(4.524195--->4.249089) 	 Saving The Model
# Epoch 13 has accurcy score of train data: 0.575
# Epoch 15 		 Training Loss: 2.6344646215438843 		 Validation Loss: 2.634319543838501
# Validation Loss Decreased(4.249089--->2.634320) 	 Saving The Model
# Epoch 14 has accurcy score of train data: 0.696
# Epoch 16 		 Training Loss: 1.6860002279281616 		 Validation Loss: 3.280111789703369
# Epoch 15 has accurcy score of train data: 0.621
# Epoch 17 		 Training Loss: 1.9545557498931885 		 Validation Loss: 2.4526634216308594
# Validation Loss Decreased(2.634320--->2.452663) 	 Saving The Model
# Epoch 16 has accurcy score of train data: 0.611
# Epoch 18 		 Training Loss: 1.6303220391273499 		 Validation Loss: 1.702680230140686
# Validation Loss Decreased(2.452663--->1.702680) 	 Saving The Model
# Epoch 17 has accurcy score of train data: 0.668
# Epoch 19 		 Training Loss: 1.149455189704895 		 Validation Loss: 2.691514015197754
# Epoch 18 has accurcy score of train data: 0.662
# Epoch 20 		 Training Loss: 1.2811893820762634 		 Validation Loss: 1.9098278284072876
# Epoch 19 has accurcy score of train data: 0.709
# Epoch 21 		 Training Loss: 1.0820464789867401 		 Validation Loss: 1.11417818069458
# Validation Loss Decreased(1.702680--->1.114178) 	 Saving The Model
# Epoch 20 has accurcy score of train data: 0.737
# Epoch 22 		 Training Loss: 0.9016682505607605 		 Validation Loss: 1.113787055015564
# Validation Loss Decreased(1.114178--->1.113787) 	 Saving The Model
# Epoch 21 has accurcy score of train data: 0.729
# Epoch 23 		 Training Loss: 0.8822236359119415 		 Validation Loss: 1.1168972253799438
# Epoch 22 has accurcy score of train data: 0.747
# Epoch 24 		 Training Loss: 0.7309659719467163 		 Validation Loss: 1.065264105796814
# Validation Loss Decreased(1.113787--->1.065264) 	 Saving The Model
# Epoch 23 has accurcy score of train data: 0.804
# Epoch 25 		 Training Loss: 0.7110910415649414 		 Validation Loss: 1.0699869394302368
# Epoch 24 has accurcy score of train data: 0.807
# Epoch 26 		 Training Loss: 0.6268777847290039 		 Validation Loss: 1.1382474899291992
# Epoch 25 has accurcy score of train data: 0.822
# Epoch 27 		 Training Loss: 0.5950636565685272 		 Validation Loss: 0.9368411302566528
# Validation Loss Decreased(1.065264--->0.936841) 	 Saving The Model
# Epoch 26 has accurcy score of train data: 0.809
# Epoch 28 		 Training Loss: 0.5744388401508331 		 Validation Loss: 0.8268563151359558
# Validation Loss Decreased(0.936841--->0.826856) 	 Saving The Model
# Epoch 27 has accurcy score of train data: 0.814
# Epoch 29 		 Training Loss: 0.5158963203430176 		 Validation Loss: 0.7607765793800354
# Validation Loss Decreased(0.826856--->0.760777) 	 Saving The Model
# Epoch 28 has accurcy score of train data: 0.869
# Epoch 30 		 Training Loss: 0.5011630356311798 		 Validation Loss: 0.8160752058029175
# Epoch 29 has accurcy score of train data: 0.843
# Epoch 31 		 Training Loss: 0.47613227367401123 		 Validation Loss: 0.839963972568512
# Epoch 30 has accurcy score of train data: 0.853
# Epoch 32 		 Training Loss: 0.484260156750679 		 Validation Loss: 0.9178503155708313
# Epoch 31 has accurcy score of train data: 0.832
# Epoch 33 		 Training Loss: 0.46950100362300873 		 Validation Loss: 0.7255224585533142
# Validation Loss Decreased(0.760777--->0.725522) 	 Saving The Model
# Epoch 32 has accurcy score of train data: 0.845
# Epoch 34 		 Training Loss: 0.4830514192581177 		 Validation Loss: 0.7984111309051514
# Epoch 33 has accurcy score of train data: 0.866
# Epoch 35 		 Training Loss: 0.44847120344638824 		 Validation Loss: 0.8038833737373352
# Epoch 34 has accurcy score of train data: 0.871
# Epoch 36 		 Training Loss: 0.40090955793857574 		 Validation Loss: 0.7691107988357544
# Epoch 35 has accurcy score of train data: 0.856
# Epoch 37 		 Training Loss: 0.4036879241466522 		 Validation Loss: 0.8761085271835327
# Epoch 36 has accurcy score of train data: 0.866
# Epoch 38 		 Training Loss: 0.38057366013526917 		 Validation Loss: 0.8217149376869202
# Epoch 37 has accurcy score of train data: 0.892
# Epoch 39 		 Training Loss: 0.3369234651327133 		 Validation Loss: 0.75240159034729
# Epoch 38 has accurcy score of train data: 0.881
# Epoch 40 		 Training Loss: 0.3616580218076706 		 Validation Loss: 0.7825252413749695
# Epoch 39 has accurcy score of train data: 0.869
# Epoch 41 		 Training Loss: 0.32061029970645905 		 Validation Loss: 0.810302734375
# Epoch 40 has accurcy score of train data: 0.889
# Epoch 42 		 Training Loss: 0.3203748017549515 		 Validation Loss: 0.7883910536766052
# Epoch 41 has accurcy score of train data: 0.892
# Epoch 43 		 Training Loss: 0.31045956909656525 		 Validation Loss: 0.7734222412109375
# Epoch 42 has accurcy score of train data: 0.892
# Epoch 44 		 Training Loss: 0.2965831309556961 		 Validation Loss: 0.7429108619689941
# Epoch 43 has accurcy score of train data: 0.918
# Epoch 45 		 Training Loss: 0.2869887053966522 		 Validation Loss: 0.7725946307182312
# Epoch 44 has accurcy score of train data: 0.905
# Epoch 46 		 Training Loss: 0.2766767144203186 		 Validation Loss: 0.8793423175811768
# Epoch 45 has accurcy score of train data: 0.920
# Epoch 47 		 Training Loss: 0.2706979662179947 		 Validation Loss: 0.8064623475074768
# Epoch 46 has accurcy score of train data: 0.918
# Epoch 48 		 Training Loss: 0.2570180296897888 		 Validation Loss: 0.8610655069351196
# Epoch 47 has accurcy score of train data: 0.941
# Epoch 49 		 Training Loss: 0.26564033329486847 		 Validation Loss: 0.8373798131942749
# Epoch 48 has accurcy score of train data: 0.918
# Epoch 50 		 Training Loss: 0.2455904856324196 		 Validation Loss: 0.8581383228302002
# Epoch 49 has accurcy score of train data: 0.923
# Epoch 51 		 Training Loss: 0.23824097961187363 		 Validation Loss: 0.8663060069084167
# Epoch 50 has accurcy score of train data: 0.930
# Epoch 52 		 Training Loss: 0.2243828922510147 		 Validation Loss: 0.8333377242088318
# Epoch 51 has accurcy score of train data: 0.930
# Epoch 53 		 Training Loss: 0.22288550436496735 		 Validation Loss: 0.8998344540596008
# Epoch 52 has accurcy score of train data: 0.923
# Epoch 54 		 Training Loss: 0.21138294786214828 		 Validation Loss: 0.9350504875183105
# Epoch 53 has accurcy score of train data: 0.923
# Epoch 55 		 Training Loss: 0.2067769393324852 		 Validation Loss: 0.9160425066947937
# Epoch 54 has accurcy score of train data: 0.936
# Epoch 56 		 Training Loss: 0.2088528797030449 		 Validation Loss: 0.9414216876029968
# Epoch 55 has accurcy score of train data: 0.902
# Epoch 57 		 Training Loss: 0.21391494572162628 		 Validation Loss: 0.9617674350738525
# Epoch 56 has accurcy score of train data: 0.925
# Epoch 58 		 Training Loss: 0.29566436260938644 		 Validation Loss: 1.0786430835723877
# Epoch 57 has accurcy score of train data: 0.887
# Epoch 59 		 Training Loss: 0.26053617149591446 		 Validation Loss: 1.0752716064453125
# Epoch 58 has accurcy score of train data: 0.876
# Epoch 60 		 Training Loss: 0.3019469529390335 		 Validation Loss: 1.1303919553756714
# Epoch 59 has accurcy score of train data: 0.897
# Epoch 61 		 Training Loss: 0.28265029937028885 		 Validation Loss: 1.0000272989273071
# Epoch 60 has accurcy score of train data: 0.925
# Epoch 62 		 Training Loss: 0.22751736640930176 		 Validation Loss: 1.1217552423477173
# Epoch 61 has accurcy score of train data: 0.910
# Epoch 63 		 Training Loss: 0.23674622178077698 		 Validation Loss: 0.9812004566192627
# Epoch 62 has accurcy score of train data: 0.915
# Epoch 64 		 Training Loss: 0.23309742659330368 		 Validation Loss: 1.1005507707595825
# Epoch 63 has accurcy score of train data: 0.912
# Epoch 65 		 Training Loss: 0.2522575557231903 		 Validation Loss: 1.0421985387802124
# Epoch 64 has accurcy score of train data: 0.948
# Epoch 66 		 Training Loss: 0.23452800512313843 		 Validation Loss: 1.004921317100525
# Epoch 65 has accurcy score of train data: 0.920
# Epoch 67 		 Training Loss: 0.19532198458909988 		 Validation Loss: 1.1567453145980835
# Epoch 66 has accurcy score of train data: 0.920
# Epoch 68 		 Training Loss: 0.20830001682043076 		 Validation Loss: 1.0101195573806763
# Epoch 67 has accurcy score of train data: 0.907
# Epoch 69 		 Training Loss: 0.18381477892398834 		 Validation Loss: 1.1054433584213257
# Epoch 68 has accurcy score of train data: 0.948
# Epoch 70 		 Training Loss: 0.1764654591679573 		 Validation Loss: 1.1309195756912231
# Epoch 69 has accurcy score of train data: 0.943
# Epoch 71 		 Training Loss: 0.15762321650981903 		 Validation Loss: 1.0635358095169067
# Epoch 70 has accurcy score of train data: 0.951
# Epoch 72 		 Training Loss: 0.18594302237033844 		 Validation Loss: 1.1140782833099365
# Epoch 71 has accurcy score of train data: 0.946
# Epoch 73 		 Training Loss: 0.154148168861866 		 Validation Loss: 1.1482619047164917
# Epoch 72 has accurcy score of train data: 0.951
# Epoch 74 		 Training Loss: 0.14810195565223694 		 Validation Loss: 1.0572036504745483
# Epoch 73 has accurcy score of train data: 0.936
# Epoch 75 		 Training Loss: 0.14603333920240402 		 Validation Loss: 1.0676766633987427
# Epoch 74 has accurcy score of train data: 0.954
# Epoch 76 		 Training Loss: 0.14045017212629318 		 Validation Loss: 1.213651180267334
# Epoch 75 has accurcy score of train data: 0.959
# Epoch 77 		 Training Loss: 0.1992500051856041 		 Validation Loss: 1.066270112991333
# Epoch 76 has accurcy score of train data: 0.959
# Epoch 78 		 Training Loss: 0.22182294726371765 		 Validation Loss: 1.2344608306884766
# Epoch 77 has accurcy score of train data: 0.881
# Epoch 79 		 Training Loss: 0.2837512791156769 		 Validation Loss: 1.6854772567749023
# Epoch 78 has accurcy score of train data: 0.835
# Epoch 80 		 Training Loss: 0.6486456394195557 		 Validation Loss: 1.173994779586792
# Epoch 79 has accurcy score of train data: 0.869
# Epoch 81 		 Training Loss: 0.3824302554130554 		 Validation Loss: 1.7288727760314941
# Epoch 80 has accurcy score of train data: 0.809
# Epoch 82 		 Training Loss: 0.5292011648416519 		 Validation Loss: 1.3544141054153442
# Epoch 81 has accurcy score of train data: 0.851
# Epoch 83 		 Training Loss: 0.5274956226348877 		 Validation Loss: 1.1108084917068481
# Epoch 82 has accurcy score of train data: 0.907
# Epoch 84 		 Training Loss: 0.3146393746137619 		 Validation Loss: 1.6118088960647583
# Epoch 83 has accurcy score of train data: 0.845
# Epoch 85 		 Training Loss: 0.3681422919034958 		 Validation Loss: 1.0651379823684692
# Epoch 84 has accurcy score of train data: 0.884
# Epoch 86 		 Training Loss: 0.3631308004260063 		 Validation Loss: 1.1458320617675781
# Epoch 85 has accurcy score of train data: 0.874
# Epoch 87 		 Training Loss: 0.3000139743089676 		 Validation Loss: 1.2384368181228638
# Epoch 86 has accurcy score of train data: 0.899
# Epoch 88 		 Training Loss: 0.2587053030729294 		 Validation Loss: 1.3786216974258423
# Epoch 87 has accurcy score of train data: 0.905
# Epoch 89 		 Training Loss: 0.23745471984148026 		 Validation Loss: 1.1308815479278564
# Epoch 88 has accurcy score of train data: 0.941
# Epoch 90 		 Training Loss: 0.2059032991528511 		 Validation Loss: 1.1000490188598633
# Epoch 89 has accurcy score of train data: 0.941
# Epoch 91 		 Training Loss: 0.17905142903327942 		 Validation Loss: 1.0577716827392578
# Epoch 90 has accurcy score of train data: 0.930
# Epoch 92 		 Training Loss: 0.20039735734462738 		 Validation Loss: 1.2173272371292114
# Epoch 91 has accurcy score of train data: 0.930
# Epoch 93 		 Training Loss: 0.16332098841667175 		 Validation Loss: 1.1795483827590942
# Epoch 92 has accurcy score of train data: 0.954
# Epoch 94 		 Training Loss: 0.16630680859088898 		 Validation Loss: 1.134811520576477
# Epoch 93 has accurcy score of train data: 0.946
# Epoch 95 		 Training Loss: 0.12450960651040077 		 Validation Loss: 1.250271201133728
# Epoch 94 has accurcy score of train data: 0.959
# Epoch 96 		 Training Loss: 0.14937332272529602 		 Validation Loss: 1.1591532230377197
# Epoch 95 has accurcy score of train data: 0.969
# Epoch 97 		 Training Loss: 0.10547798499464989 		 Validation Loss: 1.140406847000122
# Epoch 96 has accurcy score of train data: 0.964
# Epoch 98 		 Training Loss: 0.12981971353292465 		 Validation Loss: 1.274614691734314
# Epoch 97 has accurcy score of train data: 0.969
# Epoch 99 		 Training Loss: 0.09713590145111084 		 Validation Loss: 1.3395527601242065
# Epoch 98 has accurcy score of train data: 0.972
# Epoch 100 		 Training Loss: 0.09687549620866776 		 Validation Loss: 1.1811268329620361
# Epoch 99 has accurcy score of train data: 0.979

# %%
training_loss = 0.0
total = 0
correct = 0

for data,label in train_loader:
    data, label = data.cuda(), label.cuda()
    prediction = model(data)
    for x,label in zip(torch.argmax(prediction,axis = 1),label):
        if x == label:
            correct += 1
        total += 1
    loss = loss_func(prediction,label)
    training_loss += loss.item() * data.size(0)

training_loss = training_loss/len(train_loader)
correct_proportion = correct/total                          
print('Testing Loss: ', training_loss)
print('Correct Predictions: ', correct_proportion)
# Out:
# Testing Loss:40.12359036505222
# Correct Predictions: 883/900

# %%
test_loss = 0.0
total = 0
correct = 0

for data,label in test_loader:
    data, label = data.cuda(), label.cuda()
    prediction = model(data)
    for x,label in zip(torch.argmax(prediction,axis = 1),label):
        if x == label:
            correct += 1
        total += 1
    loss = loss_func(prediction,label)
    test_loss += loss.item() * data.size(0)

test_loss = test_loss/len(test_loader)
correct_proportion = correct/total                          
print('Testing Loss: ', test_loss)
print('Correct Predictions: ', correct_proportion)
# Out:
# Testing Loss:118.11268329620361
# Correct Predictions: 75/100

# %% [markdown]
# ### Task 3: Fix it.
# Fix the overfitted network from the previous step (at least partially) by using regularization techniques (Dropout/Batchnorm/...) and demonstrate the results.

# %%
class FixedNeuralNetwork(nn.Module):
    def __init__(self, input_shape=28*28, num_classes=10, input_channels=1):
        super(self.__class__, self).__init__()
        self.model = nn.Sequential(
            nn.Flatten(), # This layer converts image into a vector to use Linear layers afterwards
            # Your network structure comes here
            nn.BatchNorm1d(input_shape),
            nn.Dropout(0.5),
            nn.ReLU(),
            nn.Linear(input_shape, 256),
            nn.ReLU(),
            nn.Linear(64, num_classes)
        )
        
    def forward(self, inp):       
        out = self.model(inp)
        return out

# %%
torchsummary.summary(FixedNeuralNetwork().to(device), (28*28,))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#            Flatten-1                  [-1, 784]               0
#        BatchNorm1d-2                  [-1, 784]           1,568
#               ReLU-3                  [-1, 784]               0
#            Dropout-4                  [-1, 784]               0
#             Linear-5                  [-1, 256]         200,960
#               ReLU-6                  [-1, 256]               0
#             Linear-7                   [-1, 64]          16,448
#               ReLU-8                   [-1, 64]               0
#             Linear-9                   [-1, 10]             650
# ================================================================
# Total params: 219,626
# Trainable params: 219,626
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.03
# Params size (MB): 0.84
# Estimated Total Size (MB): 0.87
# ----------------------------------------------------------------

# %%
model = FixedNeuralNetwork().to(device)
opt = torch.optim.Adam(model.parameters(), lr = 0.05)
loss_func = nn.CrossEntropyLoss()

# Your experiments, training and validation loops here
epochs = 50

min_valid_loss = np.inf

for epoch in range(epochs):
    train_loss = 0.0
    for data, labels in train_loader:
        # Transfer Data to GPU if available
        if torch.cuda.is_available():
            data, labels = data.cuda(), labels.cuda()
         
        opt.zero_grad()
        target = model(data)
        loss = loss_func(target, labels)
        loss.backward()

        opt.step()

        train_loss += loss.item()
     
    valid_loss = 0.0
    model.eval()     # Optional when not using Model Specific layer
    for data, labels in test_loader:
        # Transfer Data to GPU if available
        if torch.cuda.is_available():
            data, labels = data.cuda(), labels.cuda()
         
        target = model(data)
        loss = loss_func(target,labels)
        valid_loss += loss.item()
 
    print(f'Epoch {epoch+1} \t\t Training Loss: {train_loss / len(train_loader)} \t\t Validation Loss: {valid_loss / len(test_loader)}')
     
    if min_valid_loss > valid_loss:
        print(f'Validation Loss Decreased({min_valid_loss:.6f}--->{valid_loss:.6f}) \t Saving The Model')
        min_valid_loss = valid_loss
         
        # Saving State Dict
        torch.save(model.state_dict(), 'saved_model.pth')
# Out:
# Epoch 1 		 Training Loss: 10.449195265769958 		 Validation Loss: 28.84555435180664
# Validation Loss Decreased(inf--->28.845554) 	 Saving The Model
# Epoch 2 		 Training Loss: 18.65770387649536 		 Validation Loss: 6.690579414367676
# Validation Loss Decreased(28.845554--->6.690579) 	 Saving The Model
# Epoch 3 		 Training Loss: 5.444067120552063 		 Validation Loss: 3.228569269180298
# Validation Loss Decreased(6.690579--->3.228569) 	 Saving The Model
# Epoch 4 		 Training Loss: 2.6024450063705444 		 Validation Loss: 1.8985002040863037
# Validation Loss Decreased(3.228569--->1.898500) 	 Saving The Model
# Epoch 5 		 Training Loss: 1.8171234726905823 		 Validation Loss: 1.7838352918624878
# Validation Loss Decreased(1.898500--->1.783835) 	 Saving The Model
# Epoch 6 		 Training Loss: 1.6241376996040344 		 Validation Loss: 1.4993287324905396
# Validation Loss Decreased(1.783835--->1.499329) 	 Saving The Model
# Epoch 7 		 Training Loss: 1.3789506554603577 		 Validation Loss: 1.4001154899597168
# Validation Loss Decreased(1.499329--->1.400115) 	 Saving The Model
# Epoch 8 		 Training Loss: 1.273188591003418 		 Validation Loss: 1.2684388160705566
# Validation Loss Decreased(1.400115--->1.268439) 	 Saving The Model
# Epoch 9 		 Training Loss: 1.153796672821045 		 Validation Loss: 1.1591439247131348
# Validation Loss Decreased(1.268439--->1.159144) 	 Saving The Model
# Epoch 10 		 Training Loss: 1.01939195394516 		 Validation Loss: 1.2147022485733032
# Epoch 11 		 Training Loss: 0.9752375185489655 		 Validation Loss: 1.0983036756515503
# Validation Loss Decreased(1.159144--->1.098304) 	 Saving The Model
# Epoch 12 		 Training Loss: 0.880682110786438 		 Validation Loss: 0.9304426312446594
# Validation Loss Decreased(1.098304--->0.930443) 	 Saving The Model
# Epoch 13 		 Training Loss: 0.806975245475769 		 Validation Loss: 0.9396242499351501
# Epoch 14 		 Training Loss: 0.7245110273361206 		 Validation Loss: 1.0076487064361572
# Epoch 15 		 Training Loss: 0.64937424659729 		 Validation Loss: 1.0664756298065186
# Epoch 16 		 Training Loss: 0.5911161005496979 		 Validation Loss: 1.1087424755096436
# Epoch 17 		 Training Loss: 0.5545933544635773 		 Validation Loss: 1.0320171117782593
# Epoch 18 		 Training Loss: 0.5105596333742142 		 Validation Loss: 1.0249632596969604
# Epoch 19 		 Training Loss: 0.4732150435447693 		 Validation Loss: 1.1323981285095215
# Epoch 20 		 Training Loss: 0.4522257149219513 		 Validation Loss: 1.0978882312774658
# Epoch 21 		 Training Loss: 0.4120352864265442 		 Validation Loss: 0.9805159568786621
# Epoch 22 		 Training Loss: 0.39278531074523926 		 Validation Loss: 0.9876390099525452
# Epoch 23 		 Training Loss: 0.35341811180114746 		 Validation Loss: 0.8894355297088623
# Validation Loss Decreased(0.930443--->0.889436) 	 Saving The Model
# Epoch 24 		 Training Loss: 0.3278093487024307 		 Validation Loss: 0.910742998123169
# Epoch 25 		 Training Loss: 0.29224736988544464 		 Validation Loss: 0.9978173971176147
# Epoch 26 		 Training Loss: 0.2680247724056244 		 Validation Loss: 0.9936478137969971
# Epoch 27 		 Training Loss: 0.2754208892583847 		 Validation Loss: 1.006897211074829
# Epoch 28 		 Training Loss: 0.23563440889120102 		 Validation Loss: 1.1028738021850586
# Epoch 29 		 Training Loss: 0.2178131565451622 		 Validation Loss: 1.0416502952575684
# Epoch 30 		 Training Loss: 0.23477739095687866 		 Validation Loss: 0.9528111219406128
# Epoch 31 		 Training Loss: 0.19825150072574615 		 Validation Loss: 1.0378392934799194
# Epoch 32 		 Training Loss: 0.17204558104276657 		 Validation Loss: 0.9775039553642273
# Epoch 33 		 Training Loss: 0.18307894468307495 		 Validation Loss: 1.005605697631836
# Epoch 34 		 Training Loss: 0.16982806473970413 		 Validation Loss: 1.0480809211730957
# Epoch 35 		 Training Loss: 0.15323546528816223 		 Validation Loss: 1.0425857305526733
# Epoch 36 		 Training Loss: 0.14217490702867508 		 Validation Loss: 1.1309857368469238
# Epoch 37 		 Training Loss: 0.12264621630311012 		 Validation Loss: 1.186155915260315
# Epoch 38 		 Training Loss: 0.12816674262285233 		 Validation Loss: 1.1170439720153809
# Epoch 39 		 Training Loss: 0.10857352986931801 		 Validation Loss: 1.2497925758361816
# Epoch 40 		 Training Loss: 0.09864160791039467 		 Validation Loss: 1.3225294351577759
# Epoch 41 		 Training Loss: 0.10163192451000214 		 Validation Loss: 1.3888336420059204
# Epoch 42 		 Training Loss: 0.08416641131043434 		 Validation Loss: 1.3550505638122559
# Epoch 43 		 Training Loss: 0.10029373690485954 		 Validation Loss: 1.4006867408752441
# Epoch 44 		 Training Loss: 0.09030868858098984 		 Validation Loss: 1.4448453187942505
# Epoch 45 		 Training Loss: 0.08757862448692322 		 Validation Loss: 1.370651364326477
# Epoch 46 		 Training Loss: 0.08214527927339077 		 Validation Loss: 1.4577832221984863
# Epoch 47 		 Training Loss: 0.058576393872499466 		 Validation Loss: 1.4953094720840454
# Epoch 48 		 Training Loss: 0.0670396238565445 		 Validation Loss: 1.6227267980575562
# Epoch 49 		 Training Loss: 0.06442421115934849 		 Validation Loss: 1.470878005027771
# Epoch 50 		 Training Loss: 0.061166685074567795 		 Validation Loss: 1.538218379020691

# %%
training_loss = 0.0
total = 0
correct = 0

for data,label in train_loader:
    data, label = data.cuda(), label.cuda()
    prediction = model(data)
    for x,label in zip(torch.argmax(prediction,axis = 1),label):
        if x == label:
            correct += 1
        total += 1
    loss = loss_func(prediction,label)
    training_loss += loss.item() * data.size(0)

training_loss = training_loss/len(train_loader)
correct_proportion = correct/total                          
print('Testing Loss: ', training_loss)
print('Correct Predictions: ', correct_proportion)
# Out:
# Testing Loss:22.912328884005547
# Correct Predictions: 883/900

# %%
test_loss = 0.0
total = 0
correct = 0

for data,label in test_loader:
    data, label = data.cuda(), label.cuda()
    prediction = model(data)
    for x,label in zip(torch.argmax(prediction,axis = 1),label):
        if x == label:
            correct += 1
        total += 1
    loss = loss_func(prediction,label)
    test_loss += loss.item() * data.size(0)

test_loss = test_loss/len(test_loader)
correct_proportion = correct/total                          
print('Testing Loss: ', test_loss)
print('Correct Predictions: ', correct_proportion)
# Out:
# Testing Loss:153.8218379020691
# Correct Predictions: 76/100

# %% [markdown]
# ### Conclusions:
# _Write down small report with your conclusions and your ideas._
#
# In the first part we needed several layers to get good result and used activations and batchnorm.
# To overfit the data the easiest way is by having small data with ig training time. I fixed it by opting for regularization techniques addition.
